# %% [markdown]
# Using CBOW model

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
#preproccess
text_data = ["""I'm so happy 'cause today I found my friends
They're in my head
I'm so ugly, that's okay, 'cause so are you
Broke our mirrors
Sunday morning is everyday, for all I care
And I'm not scared
Light my candles in a daze
'Cause I've found God"""]
words = []
for sentence in text_data:
    for word in sentence.split():
        words.append(word.lower())
vocab = set(words)
word_to_idx = {word: idx for idx, word in enumerate(vocab)}
vocab_size = len(vocab)

# %% [markdown]
# Used Documentation from PyTorch to help implement

# %%
embedding_dim = 10
context_size = 2 #2 before 2 after
num_epochs = 1000
lr = 0.001

# %%
data = []
print(len(words))
for i in range(context_size, len(words) - context_size):
    #two before and two after
    context = [words[i - context_size ], words[i - (context_size-1)],
               words[i + (context_size-1)], words[i + context_size]]
    target = words[i] #word in between
    data.append((context, target))
print(data)
# Out:
# 47
# [(["i'm", 'so', "'cause", 'today'], 'happy'), (['so', 'happy', 'today', 'i'], "'cause"), (['happy', "'cause", 'i', 'found'], 'today'), (["'cause", 'today', 'found', 'my'], 'i'), (['today', 'i', 'my', 'friends'], 'found'), (['i', 'found', 'friends', "they're"], 'my'), (['found', 'my', "they're", 'in'], 'friends'), (['my', 'friends', 'in', 'my'], "they're"), (['friends', "they're", 'my', 'head'], 'in'), (["they're", 'in', 'head', "i'm"], 'my'), (['in', 'my', "i'm", 'so'], 'head'), (['my', 'head', 'so', 'ugly,'], "i'm"), (['head', "i'm", 'ugly,', "that's"], 'so'), (["i'm", 'so', "that's", 'okay,'], 'ugly,'), (['so', 'ugly,', 'okay,', "'cause"], "that's"), (['ugly,', "that's", "'cause", 'so'], 'okay,'), (["that's", 'okay,', 'so', 'are'], "'cause"), (['okay,', "'cause", 'are', 'you'], 'so'), (["'cause", 'so', 'you', 'broke'], 'are'), (['so', 'are', 'broke', 'our'], 'you'), (['are', 'you', 'our', 'mirrors'], 'broke'), (['you', 'broke', 'mirrors', 'sunday'], 'our'), (['broke', 'our', 'sunday', 'morning'], 'mirrors'), (['our', 'mirrors', 'morning', 'is'], 'sunday'), (['mirrors', 'sunday', 'is', 'everyday,'], 'morning'), (['sunday', 'morning', 'everyday,', 'for'], 'is'), (['morning', 'is', 'for', 'all'], 'everyday,'), (['is', 'everyday,', 'all', 'i'], 'for'), (['everyday,', 'for', 'i', 'care'], 'all'), (['for', 'all', 'care', 'and'], 'i'), (['all', 'i', 'and', "i'm"], 'care'), (['i', 'care', "i'm", 'not'], 'and'), (['care', 'and', 'not', 'scared'], "i'm"), (['and', "i'm", 'scared', 'light'], 'not'), (["i'm", 'not', 'light', 'my'], 'scared'), (['not', 'scared', 'my', 'candles'], 'light'), (['scared', 'light', 'candles', 'in'], 'my'), (['light', 'my', 'in', 'a'], 'candles'), (['my', 'candles', 'a', 'daze'], 'in'), (['candles', 'in', 'daze', "'cause"], 'a'), (['in', 'a', "'cause", "i've"], 'daze'), (['a', 'daze', "i've", 'found'], "'cause"), (['daze', "'cause", 'found', 'god'], "i've")]

# %%
class CBOW(nn.Module):
    def __init__(self, vocab_size, embedding_size):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear = nn.Linear(embedding_size, vocab_size)
        

    def forward(self, inputs):
        embedding = self.embeddings(inputs).mean(dim=0).view(1,-1)
        out = self.linear(embedding)
        pred = nn.functional.log_softmax(out, dim = 1)
        return pred

# %%
model = CBOW(vocab_size, embedding_dim)
crit = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
for epoch in range(1001):
    total_loss = 0
    for context, target in data:
        context_indexes = []
        for word in context:
            context_indexes.append(word_to_idx[word])
        context_indexes = torch.tensor((context_indexes),dtype= torch.long)
        model.zero_grad()
        pred = model(context_indexes)
        loss = crit(pred, torch.tensor([word_to_idx[target]], dtype=torch.long))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    if epoch % 10 == 0:
        print(f'Epoch {epoch}, Loss: {total_loss}')
# Out:
# Epoch 0, Loss: 158.8257236480713
# Epoch 10, Loss: 144.97513031959534
# Epoch 20, Loss: 132.63411116600037
# Epoch 30, Loss: 120.43028914928436
# Epoch 40, Loss: 108.18865919113159
# Epoch 50, Loss: 96.18789672851562
# Epoch 60, Loss: 84.7951335310936
# Epoch 70, Loss: 74.27168518304825
# Epoch 80, Loss: 64.72489219903946
# Epoch 90, Loss: 56.153749614953995
# Epoch 100, Loss: 48.50559261441231
# Epoch 110, Loss: 41.713062822818756
# Epoch 120, Loss: 35.71287000179291
# Epoch 130, Loss: 30.448493123054504
# Epoch 140, Loss: 25.86537890136242
# Epoch 150, Loss: 21.906123086810112
# Epoch 160, Loss: 18.509541675448418
# Epoch 170, Loss: 15.612790241837502
# Epoch 180, Loss: 13.154089234769344
# Epoch 190, Loss: 11.074930742383003
# Epoch 200, Loss: 9.321489058434963
# Epoch 210, Loss: 7.845366485416889
# Epoch 220, Loss: 6.603895734995604
# Epoch 230, Loss: 5.560068279504776
# Epoch 240, Loss: 4.682214092463255
# Epoch 250, Loss: 3.943521626293659
# Epoch 260, Loss: 3.321483777835965
# Epoch 270, Loss: 2.797292783856392
# Epoch 280, Loss: 2.3552742805331945
# Epoch 290, Loss: 1.9823747351765633
# Epoch 300, Loss: 1.6677053747698665
# Epoch 310, Loss: 1.4021682552993298
# Epoch 320, Loss: 1.1781322434544563
# Epoch 330, Loss: 0.9891819870099425
# Epoch 340, Loss: 0.8299056240357459
# Epoch 350, Loss: 0.6957294996827841
# Epoch 360, Loss: 0.5827851197682321
# Epoch 370, Loss: 0.48778826906345785
# Epoch 380, Loss: 0.4079544139094651
# Epoch 390, Loss: 0.3409220071043819
# Epoch 400, Loss: 0.2846887996420264
# Epoch 410, Loss: 0.23755437193904072
# Epoch 420, Loss: 0.19808151735924184
# Epoch 430, Loss: 0.16505326004698873
# Epoch 440, Loss: 0.13743846316356212
# Epoch 450, Loss: 0.1143688039155677
# Epoch 460, Loss: 0.09511149424361065
# Epoch 470, Loss: 0.07904641248751432
# Epoch 480, Loss: 0.06565591401886195
# Epoch 490, Loss: 0.05450355130597018
# Epoch 500, Loss: 0.04521842981921509
# Epoch 510, Loss: 0.037494871707167476
# Epoch 520, Loss: 0.031074062761035748
# Epoch 530, Loss: 0.025739520468050614
# Epoch 540, Loss: 0.021310603158781305
# Epoch 550, Loss: 0.017635355186939705
# Epoch 560, Loss: 0.014585468263248913
# Epoch 570, Loss: 0.012058721731591504
# Epoch 580, Loss: 0.009964488363038981
# Epoch 590, Loss: 0.008231384093960514
# Epoch 600, Loss: 0.006795493340177927
# Epoch 610, Loss: 0.00560788774600951
# Epoch 620, Loss: 0.004627129159416654
# Epoch 630, Loss: 0.00381534105144965
# Epoch 640, Loss: 0.0031448883455595933
# Epoch 650, Loss: 0.002592182439911994
# Epoch 660, Loss: 0.0021333920531105832
# Epoch 670, Loss: 0.001757437079504598
# Epoch 680, Loss: 0.0014475140333161107
# Epoch 690, Loss: 0.001190990019495075
# Epoch 700, Loss: 0.0009797608727240004
# Epoch 710, Loss: 0.0008059603210313071
# Epoch 720, Loss: 0.0006619599434998236
# Epoch 730, Loss: 0.000543945757954134
# Epoch 740, Loss: 0.00044703063622364425
# Epoch 750, Loss: 0.0003669233626624191
# Epoch 760, Loss: 0.0003021936350933174
# Epoch 770, Loss: 0.0002474772019240845
# Epoch 780, Loss: 0.00020384701088005386
# Epoch 790, Loss: 0.00016629637673304387
# Epoch 800, Loss: 0.00013732870877447567
# Epoch 810, Loss: 0.00011229488666231191
# Epoch 820, Loss: 9.155255975201726e-05
# Epoch 830, Loss: 7.569777932303623e-05
# Epoch 840, Loss: 6.222716899628722e-05
# Epoch 850, Loss: 5.030626817870143e-05
# Epoch 860, Loss: 4.184242459359666e-05
# Epoch 870, Loss: 3.4332251502178224e-05
# Epoch 880, Loss: 2.7656539486997644e-05
# Epoch 890, Loss: 2.288817248796704e-05
# Epoch 900, Loss: 1.8596642171075928e-05
# Epoch 910, Loss: 1.5377993229037656e-05
# Epoch 920, Loss: 1.2755390528695898e-05
# Epoch 930, Loss: 1.0251996613419578e-05
# Epoch 940, Loss: 8.225439579234717e-06
# Epoch 950, Loss: 6.914137813396337e-06
# Epoch 960, Loss: 6.19888228925447e-06
# Epoch 970, Loss: 4.7683710349133435e-06
# Epoch 980, Loss: 4.529952555287764e-06
# Epoch 990, Loss: 3.93390623543155e-06
# Epoch 1000, Loss: 2.9802320042904284e-06

# %%
embeddings = model.embeddings.weight.data
for i, word in enumerate(vocab):
    for j, word2 in enumerate(vocab):
        #Cosine Similarity is basically comparing vectors (dot product of both divided by product of magnitudes)
        #The closer their values, the closer to one the values should be. 
        # The dissimilarity should be 1 - cosine dissimilarity
        print(f'Cosine Similarity between {word} and {word2}: {nn.functional.cosine_similarity(embeddings[i],embeddings[j],dim = 0)}')
        print(f'Cosine Dissimilarity between {word} and {word2}: {1- nn.functional.cosine_similarity(embeddings[i],embeddings[j],dim = 0)}')
# Out:
# Cosine Similarity between okay, and okay,: 1.0000001192092896
# Cosine Dissimilarity between okay, and okay,: -1.1920928955078125e-07
# Cosine Similarity between okay, and god: 0.3150038421154022
# Cosine Dissimilarity between okay, and god: 0.6849961280822754
# Cosine Similarity between okay, and candles: 0.03175738453865051
# Cosine Dissimilarity between okay, and candles: 0.9682426452636719
# Cosine Similarity between okay, and not: 0.12313272058963776
# Cosine Dissimilarity between okay, and not: 0.8768672943115234
# Cosine Similarity between okay, and you: -0.22057007253170013
# Cosine Dissimilarity between okay, and you: 1.2205700874328613
# Cosine Similarity between okay, and found: -0.10158276557922363
# Cosine Dissimilarity between okay, and found: 1.1015827655792236
# Cosine Similarity between okay, and is: -0.6610755920410156
# Cosine Dissimilarity between okay, and is: 1.6610755920410156
# Cosine Similarity between okay, and 'cause: -0.22449742257595062
# Cosine Dissimilarity between okay, and 'cause: 1.2244974374771118
# Cosine Similarity between okay, and sunday: -0.04638919234275818
# Cosine Dissimilarity between okay, and sunday: 1.0463892221450806
# Cosine Similarity between okay, and broke: -0.058269597589969635
# Cosine Dissimilarity between okay, and broke: 1.0582696199417114
# Cosine Similarity between okay, and ugly,: 0.08052393794059753
# Cosine Dissimilarity between okay, and ugly,: 0.9194760322570801
# Cosine Similarity between okay, and and: -0.16927435994148254
# Cosine Dissimilarity between okay, and and: 1.1692743301391602
# Cosine Similarity between okay, and happy: 0.3723609447479248
# Cosine Dissimilarity between okay, and happy: 0.6276390552520752
# Cosine Similarity between okay, and all: -0.5379530787467957
# Cosine Dissimilarity between okay, and all: 1.5379531383514404
# Cosine Similarity between okay, and everyday,: -0.14652621746063232
# Cosine Dissimilarity between okay, and everyday,: 1.1465262174606323
# Cosine Similarity between okay, and so: 0.4509563148021698
# Cosine Dissimilarity between okay, and so: 0.5490436553955078
# Cosine Similarity between okay, and light: 0.1794007420539856
# Cosine Dissimilarity between okay, and light: 0.8205992579460144
# Cosine Similarity between okay, and our: -0.20524729788303375
# Cosine Dissimilarity between okay, and our: 1.2052472829818726
# Cosine Similarity between okay, and my: -0.03678562864661217
# Cosine Dissimilarity between okay, and my: 1.03678560256958
# Cosine Similarity between okay, and a: 0.4227021038532257
# Cosine Dissimilarity between okay, and a: 0.5772979259490967
# Cosine Similarity between okay, and are: 0.18554089963436127
# Cosine Dissimilarity between okay, and are: 0.8144590854644775
# Cosine Similarity between okay, and i've: 0.43225905299186707
# Cosine Dissimilarity between okay, and i've: 0.5677409172058105
# Cosine Similarity between okay, and care: -0.3087938129901886
# Cosine Dissimilarity between okay, and care: 1.3087937831878662
# Cosine Similarity between okay, and i: 0.4564479887485504
# Cosine Dissimilarity between okay, and i: 0.543552041053772
# Cosine Similarity between okay, and friends: 0.0440686009824276
# Cosine Dissimilarity between okay, and friends: 0.9559314250946045
# Cosine Similarity between okay, and today: -0.1474420577287674
# Cosine Dissimilarity between okay, and today: 1.147442102432251
# Cosine Similarity between okay, and i'm: 0.2537425458431244
# Cosine Dissimilarity between okay, and i'm: 0.7462574243545532
# Cosine Similarity between okay, and scared: 0.5195048451423645
# Cosine Dissimilarity between okay, and scared: 0.4804951548576355
# Cosine Similarity between okay, and mirrors: -0.23232948780059814
# Cosine Dissimilarity between okay, and mirrors: 1.2323294878005981
# Cosine Similarity between okay, and for: -0.2703299820423126
# Cosine Dissimilarity between okay, and for: 1.2703299522399902
# Cosine Similarity between okay, and head: 0.015615272335708141
# Cosine Dissimilarity between okay, and head: 0.9843847155570984
# Cosine Similarity between okay, and daze: -0.01880183443427086
# Cosine Dissimilarity between okay, and daze: 1.0188018083572388
# Cosine Similarity between okay, and in: 0.19654832780361176
# Cosine Dissimilarity between okay, and in: 0.803451657295227
# Cosine Similarity between okay, and morning: -0.5358100533485413
# Cosine Dissimilarity between okay, and morning: 1.5358099937438965
# Cosine Similarity between okay, and they're: 0.4292074143886566
# Cosine Dissimilarity between okay, and they're: 0.570792555809021
# Cosine Similarity between okay, and that's: -0.10822876542806625
# Cosine Dissimilarity between okay, and that's: 1.1082288026809692
# Cosine Similarity between god and okay,: 0.3150038421154022
# Cosine Dissimilarity between god and okay,: 0.6849961280822754
# Cosine Similarity between god and god: 1.0
# Cosine Dissimilarity between god and god: 0.0
# Cosine Similarity between god and candles: 0.18413794040679932
# Cosine Dissimilarity between god and candles: 0.8158620595932007
# Cosine Similarity between god and not: 0.18036001920700073
# Cosine Dissimilarity between god and not: 0.8196399807929993
# Cosine Similarity between god and you: -0.40791213512420654
# Cosine Dissimilarity between god and you: 1.4079121351242065
# Cosine Similarity between god and found: 0.4868764281272888
# Cosine Dissimilarity between god and found: 0.5131235718727112
# Cosine Similarity between god and is: -0.5450412034988403
# Cosine Dissimilarity between god and is: 1.5450412034988403
# Cosine Similarity between god and 'cause: 0.17769154906272888
# Cosine Dissimilarity between god and 'cause: 0.8223084211349487
# Cosine Similarity between god and sunday: -0.7017813920974731
# Cosine Dissimilarity between god and sunday: 1.7017813920974731
# Cosine Similarity between god and broke: -0.647267758846283
# Cosine Dissimilarity between god and broke: 1.6472678184509277
# Cosine Similarity between god and ugly,: 0.0032624751329421997
# Cosine Dissimilarity between god and ugly,: 0.996737539768219
# Cosine Similarity between god and and: 0.043158695101737976
# Cosine Dissimilarity between god and and: 0.9568412899971008
# Cosine Similarity between god and happy: 0.11013540625572205
# Cosine Dissimilarity between god and happy: 0.8898645639419556
# Cosine Similarity between god and all: -0.099148228764534
# Cosine Dissimilarity between god and all: 1.0991482734680176
# Cosine Similarity between god and everyday,: -0.4962439239025116
# Cosine Dissimilarity between god and everyday,: 1.496243953704834
# Cosine Similarity between god and so: 0.03944852948188782
# Cosine Dissimilarity between god and so: 0.9605515003204346
# Cosine Similarity between god and light: -0.07781032472848892
# Cosine Dissimilarity between god and light: 1.077810287475586
# Cosine Similarity between god and our: 0.11714979261159897
# Cosine Dissimilarity between god and our: 0.8828502297401428
# Cosine Similarity between god and my: 0.11148647964000702
# Cosine Dissimilarity between god and my: 0.8885135054588318
# Cosine Similarity between god and a: 0.0517793707549572
# Cosine Dissimilarity between god and a: 0.9482206106185913
# Cosine Similarity between god and are: 0.34470564126968384
# Cosine Dissimilarity between god and are: 0.6552943587303162
# Cosine Similarity between god and i've: -0.38684532046318054
# Cosine Dissimilarity between god and i've: 1.386845350265503
# Cosine Similarity between god and care: 0.1587592512369156
# Cosine Dissimilarity between god and care: 0.8412407636642456
# Cosine Similarity between god and i: 0.2006232887506485
# Cosine Dissimilarity between god and i: 0.7993767261505127
# Cosine Similarity between god and friends: -0.16485369205474854
# Cosine Dissimilarity between god and friends: 1.1648536920547485
# Cosine Similarity between god and today: 0.09367022663354874
# Cosine Dissimilarity between god and today: 0.9063297510147095
# Cosine Similarity between god and i'm: 0.3480612635612488
# Cosine Dissimilarity between god and i'm: 0.6519387364387512
# Cosine Similarity between god and scared: -0.19678790867328644
# Cosine Dissimilarity between god and scared: 1.19678795337677
# Cosine Similarity between god and mirrors: -0.04992012679576874
# Cosine Dissimilarity between god and mirrors: 1.0499200820922852
# Cosine Similarity between god and for: -0.2734118700027466
# Cosine Dissimilarity between god and for: 1.2734118700027466
# Cosine Similarity between god and head: 0.007675759494304657
# Cosine Dissimilarity between god and head: 0.9923242330551147
# Cosine Similarity between god and daze: 0.5165854096412659
# Cosine Dissimilarity between god and daze: 0.48341459035873413
# Cosine Similarity between god and in: -0.3391059339046478
# Cosine Dissimilarity between god and in: 1.3391059637069702
# Cosine Similarity between god and morning: -0.4926530420780182
# Cosine Dissimilarity between god and morning: 1.4926530122756958
# Cosine Similarity between god and they're: 0.3157722055912018
# Cosine Dissimilarity between god and they're: 0.6842278242111206
# Cosine Similarity between god and that's: 0.34517809748649597
# Cosine Dissimilarity between god and that's: 0.6548218727111816
# Cosine Similarity between candles and okay,: 0.03175738453865051
# Cosine Dissimilarity between candles and okay,: 0.9682426452636719
# Cosine Similarity between candles and god: 0.18413794040679932
# Cosine Dissimilarity between candles and god: 0.8158620595932007
# Cosine Similarity between candles and candles: 1.0
# Cosine Dissimilarity between candles and candles: 0.0
# Cosine Similarity between candles and not: 0.0314980149269104
# Cosine Dissimilarity between candles and not: 0.9685019850730896
# Cosine Similarity between candles and you: -0.18839792907238007
# Cosine Dissimilarity between candles and you: 1.1883978843688965
# Cosine Similarity between candles and found: 0.32865503430366516
# Cosine Dissimilarity between candles and found: 0.6713449954986572
# Cosine Similarity between candles and is: -0.22453923523426056
# Cosine Dissimilarity between candles and is: 1.2245392799377441
# Cosine Similarity between candles and 'cause: 0.05234187841415405
# Cosine Dissimilarity between candles and 'cause: 0.947658121585846
# Cosine Similarity between candles and sunday: -0.005820423364639282
# Cosine Dissimilarity between candles and sunday: 1.005820393562317
# Cosine Similarity between candles and broke: -0.5644981265068054
# Cosine Dissimilarity between candles and broke: 1.5644981861114502
# Cosine Similarity between candles and ugly,: -0.43664565682411194
# Cosine Dissimilarity between candles and ugly,: 1.4366456270217896
# Cosine Similarity between candles and and: -0.4445224702358246
# Cosine Dissimilarity between candles and and: 1.444522500038147
# Cosine Similarity between candles and happy: -0.10357330739498138
# Cosine Dissimilarity between candles and happy: 1.1035733222961426
# Cosine Similarity between candles and all: 0.18615347146987915
# Cosine Dissimilarity between candles and all: 0.8138465285301208
# Cosine Similarity between candles and everyday,: 0.35472601652145386
# Cosine Dissimilarity between candles and everyday,: 0.6452739834785461
# Cosine Similarity between candles and so: -0.7317820191383362
# Cosine Dissimilarity between candles and so: 1.7317819595336914
# Cosine Similarity between candles and light: 0.46584200859069824
# Cosine Dissimilarity between candles and light: 0.5341579914093018
# Cosine Similarity between candles and our: -0.5428681969642639
# Cosine Dissimilarity between candles and our: 1.5428681373596191
# Cosine Similarity between candles and my: -0.11601722240447998
# Cosine Dissimilarity between candles and my: 1.11601722240448
# Cosine Similarity between candles and a: 0.26292523741722107
# Cosine Dissimilarity between candles and a: 0.7370747327804565
# Cosine Similarity between candles and are: 0.11500519514083862
# Cosine Dissimilarity between candles and are: 0.8849948048591614
# Cosine Similarity between candles and i've: -0.25361910462379456
# Cosine Dissimilarity between candles and i've: 1.2536190748214722
# Cosine Similarity between candles and care: -0.005046844482421875
# Cosine Dissimilarity between candles and care: 1.0050468444824219
# Cosine Similarity between candles and i: 0.4649508595466614
# Cosine Dissimilarity between candles and i: 0.5350491404533386
# Cosine Similarity between candles and friends: 0.37017887830734253
# Cosine Dissimilarity between candles and friends: 0.6298211216926575
# Cosine Similarity between candles and today: -0.08316247165203094
# Cosine Dissimilarity between candles and today: 1.0831624269485474
# Cosine Similarity between candles and i'm: -0.04281723499298096
# Cosine Dissimilarity between candles and i'm: 1.042817234992981
# Cosine Similarity between candles and scared: 0.006102368235588074
# Cosine Dissimilarity between candles and scared: 0.9938976168632507
# Cosine Similarity between candles and mirrors: 0.08713071793317795
# Cosine Dissimilarity between candles and mirrors: 0.9128692746162415
# Cosine Similarity between candles and for: 0.19108986854553223
# Cosine Dissimilarity between candles and for: 0.8089101314544678
# Cosine Similarity between candles and head: 0.3731675148010254
# Cosine Dissimilarity between candles and head: 0.6268324851989746
# Cosine Similarity between candles and daze: 0.43755486607551575
# Cosine Dissimilarity between candles and daze: 0.5624451637268066
# Cosine Similarity between candles and in: 0.23663753271102905
# Cosine Dissimilarity between candles and in: 0.763362467288971
# Cosine Similarity between candles and morning: -0.2776449918746948
# Cosine Dissimilarity between candles and morning: 1.2776449918746948
# Cosine Similarity between candles and they're: 0.5385355949401855
# Cosine Dissimilarity between candles and they're: 0.46146440505981445
# Cosine Similarity between candles and that's: 0.3170907497406006
# Cosine Dissimilarity between candles and that's: 0.6829092502593994
# Cosine Similarity between not and okay,: 0.12313272058963776
# Cosine Dissimilarity between not and okay,: 0.8768672943115234
# Cosine Similarity between not and god: 0.18036001920700073
# Cosine Dissimilarity between not and god: 0.8196399807929993
# Cosine Similarity between not and candles: 0.0314980149269104
# Cosine Dissimilarity between not and candles: 0.9685019850730896
# Cosine Similarity between not and not: 1.0
# Cosine Dissimilarity between not and not: 0.0
# Cosine Similarity between not and you: -0.11930298805236816
# Cosine Dissimilarity between not and you: 1.1193029880523682
# Cosine Similarity between not and found: -0.1549879014492035
# Cosine Dissimilarity between not and found: 1.1549879312515259
# Cosine Similarity between not and is: -0.20315492153167725
# Cosine Dissimilarity between not and is: 1.2031549215316772
# Cosine Similarity between not and 'cause: 0.37514618039131165
# Cosine Dissimilarity between not and 'cause: 0.6248538494110107
# Cosine Similarity between not and sunday: -0.16504168510437012
# Cosine Dissimilarity between not and sunday: 1.1650416851043701
# Cosine Similarity between not and broke: -0.14624515175819397
# Cosine Dissimilarity between not and broke: 1.1462451219558716
# Cosine Similarity between not and ugly,: 0.5545917749404907
# Cosine Dissimilarity between not and ugly,: 0.4454082250595093
# Cosine Similarity between not and and: -0.10996212065219879
# Cosine Dissimilarity between not and and: 1.1099621057510376
# Cosine Similarity between not and happy: -0.4632616639137268
# Cosine Dissimilarity between not and happy: 1.463261604309082
# Cosine Similarity between not and all: -0.31440073251724243
# Cosine Dissimilarity between not and all: 1.3144006729125977
# Cosine Similarity between not and everyday,: 0.47093451023101807
# Cosine Dissimilarity between not and everyday,: 0.5290654897689819
# Cosine Similarity between not and so: 0.01876494660973549
# Cosine Dissimilarity between not and so: 0.9812350273132324
# Cosine Similarity between not and light: -0.047845229506492615
# Cosine Dissimilarity between not and light: 1.0478452444076538
# Cosine Similarity between not and our: -0.5101228952407837
# Cosine Dissimilarity between not and our: 1.5101228952407837
# Cosine Similarity between not and my: 0.3176974654197693
# Cosine Dissimilarity between not and my: 0.6823025345802307
# Cosine Similarity between not and a: -0.3167668879032135
# Cosine Dissimilarity between not and a: 1.3167668581008911
# Cosine Similarity between not and are: -0.2737117111682892
# Cosine Dissimilarity between not and are: 1.2737116813659668
# Cosine Similarity between not and i've: -0.2871379256248474
# Cosine Dissimilarity between not and i've: 1.2871379852294922
# Cosine Similarity between not and care: 0.32256436347961426
# Cosine Dissimilarity between not and care: 0.6774356365203857
# Cosine Similarity between not and i: 0.06176046282052994
# Cosine Dissimilarity between not and i: 0.9382395148277283
# Cosine Similarity between not and friends: 0.21039533615112305
# Cosine Dissimilarity between not and friends: 0.789604663848877
# Cosine Similarity between not and today: -0.34467849135398865
# Cosine Dissimilarity between not and today: 1.344678521156311
# Cosine Similarity between not and i'm: 0.19840750098228455
# Cosine Dissimilarity between not and i'm: 0.8015924692153931
# Cosine Similarity between not and scared: 0.2215975522994995
# Cosine Dissimilarity between not and scared: 0.7784024477005005
# Cosine Similarity between not and mirrors: -0.19036725163459778
# Cosine Dissimilarity between not and mirrors: 1.1903672218322754
# Cosine Similarity between not and for: -0.42985808849334717
# Cosine Dissimilarity between not and for: 1.4298580884933472
# Cosine Similarity between not and head: 0.3601290285587311
# Cosine Dissimilarity between not and head: 0.6398710012435913
# Cosine Similarity between not and daze: -0.10159841924905777
# Cosine Dissimilarity between not and daze: 1.1015983819961548
# Cosine Similarity between not and in: -0.4777258038520813
# Cosine Dissimilarity between not and in: 1.4777257442474365
# Cosine Similarity between not and morning: -0.6556693315505981
# Cosine Dissimilarity between not and morning: 1.6556693315505981
# Cosine Similarity between not and they're: -0.1880468726158142
# Cosine Dissimilarity between not and they're: 1.188046932220459
# Cosine Similarity between not and that's: -0.4321781396865845
# Cosine Dissimilarity between not and that's: 1.4321781396865845
# Cosine Similarity between you and okay,: -0.22057007253170013
# Cosine Dissimilarity between you and okay,: 1.2205700874328613
# Cosine Similarity between you and god: -0.40791213512420654
# Cosine Dissimilarity between you and god: 1.4079121351242065
# Cosine Similarity between you and candles: -0.18839792907238007
# Cosine Dissimilarity between you and candles: 1.1883978843688965
# Cosine Similarity between you and not: -0.11930298805236816
# Cosine Dissimilarity between you and not: 1.1193029880523682
# Cosine Similarity between you and you: 0.9999999403953552
# Cosine Dissimilarity between you and you: 5.960464477539063e-08
# Cosine Similarity between you and found: -0.5419589281082153
# Cosine Dissimilarity between you and found: 1.5419589281082153
# Cosine Similarity between you and is: 0.2334267795085907
# Cosine Dissimilarity between you and is: 0.7665731906890869
# Cosine Similarity between you and 'cause: 0.1346234530210495
# Cosine Dissimilarity between you and 'cause: 0.8653765320777893
# Cosine Similarity between you and sunday: 0.14505669474601746
# Cosine Dissimilarity between you and sunday: 0.8549432754516602
# Cosine Similarity between you and broke: 0.6483848094940186
# Cosine Dissimilarity between you and broke: 0.35161519050598145
# Cosine Similarity between you and ugly,: 0.33716633915901184
# Cosine Dissimilarity between you and ugly,: 0.6628336906433105
# Cosine Similarity between you and and: -0.4826695919036865
# Cosine Dissimilarity between you and and: 1.4826695919036865
# Cosine Similarity between you and happy: 0.04867016524076462
# Cosine Dissimilarity between you and happy: 0.9513298273086548
# Cosine Similarity between you and all: -0.34875085949897766
# Cosine Dissimilarity between you and all: 1.3487508296966553
# Cosine Similarity between you and everyday,: 0.020942537114024162
# Cosine Dissimilarity between you and everyday,: 0.9790574908256531
# Cosine Similarity between you and so: 0.08546657860279083
# Cosine Dissimilarity between you and so: 0.9145334362983704
# Cosine Similarity between you and light: 0.10151766985654831
# Cosine Dissimilarity between you and light: 0.8984823226928711
# Cosine Similarity between you and our: 0.043672114610672
# Cosine Dissimilarity between you and our: 0.9563279151916504
# Cosine Similarity between you and my: -0.616393506526947
# Cosine Dissimilarity between you and my: 1.6163935661315918
# Cosine Similarity between you and a: 0.013555580750107765
# Cosine Dissimilarity between you and a: 0.9864444136619568
# Cosine Similarity between you and are: 0.39848870038986206
# Cosine Dissimilarity between you and are: 0.6015112996101379
# Cosine Similarity between you and i've: 0.016395051032304764
# Cosine Dissimilarity between you and i've: 0.9836049675941467
# Cosine Similarity between you and care: -0.12638694047927856
# Cosine Dissimilarity between you and care: 1.1263868808746338
# Cosine Similarity between you and i: -0.18966540694236755
# Cosine Dissimilarity between you and i: 1.18966543674469
# Cosine Similarity between you and friends: -0.2257915884256363
# Cosine Dissimilarity between you and friends: 1.225791573524475
# Cosine Similarity between you and today: -0.30878815054893494
# Cosine Dissimilarity between you and today: 1.3087881803512573
# Cosine Similarity between you and i'm: 0.13648664951324463
# Cosine Dissimilarity between you and i'm: 0.8635133504867554
# Cosine Similarity between you and scared: -0.21726936101913452
# Cosine Dissimilarity between you and scared: 1.2172694206237793
# Cosine Similarity between you and mirrors: 0.2109616994857788
# Cosine Dissimilarity between you and mirrors: 0.7890383005142212
# Cosine Similarity between you and for: 0.24947498738765717
# Cosine Dissimilarity between you and for: 0.7505249977111816
# Cosine Similarity between you and head: 0.27497148513793945
# Cosine Dissimilarity between you and head: 0.7250285148620605
# Cosine Similarity between you and daze: 0.1285199522972107
# Cosine Dissimilarity between you and daze: 0.8714800477027893
# Cosine Similarity between you and in: -0.14529076218605042
# Cosine Dissimilarity between you and in: 1.145290732383728
# Cosine Similarity between you and morning: 0.2508746087551117
# Cosine Dissimilarity between you and morning: 0.7491253614425659
# Cosine Similarity between you and they're: -0.21310949325561523
# Cosine Dissimilarity between you and they're: 1.2131094932556152
# Cosine Similarity between you and that's: 0.21618619561195374
# Cosine Dissimilarity between you and that's: 0.7838138341903687
# Cosine Similarity between found and okay,: -0.10158276557922363
# Cosine Dissimilarity between found and okay,: 1.1015827655792236
# Cosine Similarity between found and god: 0.4868764281272888
# Cosine Dissimilarity between found and god: 0.5131235718727112
# Cosine Similarity between found and candles: 0.32865503430366516
# Cosine Dissimilarity between found and candles: 0.6713449954986572
# Cosine Similarity between found and not: -0.1549879014492035
# Cosine Dissimilarity between found and not: 1.1549879312515259
# Cosine Similarity between found and you: -0.5419589281082153
# Cosine Dissimilarity between found and you: 1.5419589281082153
# Cosine Similarity between found and found: 1.0
# Cosine Dissimilarity between found and found: 0.0
# Cosine Similarity between found and is: -0.1381683498620987
# Cosine Dissimilarity between found and is: 1.1381683349609375
# Cosine Similarity between found and 'cause: 0.24726872146129608
# Cosine Dissimilarity between found and 'cause: 0.7527312636375427
# Cosine Similarity between found and sunday: -0.5406637787818909
# Cosine Dissimilarity between found and sunday: 1.540663719177246
# Cosine Similarity between found and broke: -0.6607285737991333
# Cosine Dissimilarity between found and broke: 1.6607285737991333
# Cosine Similarity between found and ugly,: -0.2761225998401642
# Cosine Dissimilarity between found and ugly,: 1.2761225700378418
# Cosine Similarity between found and and: 0.48863306641578674
# Cosine Dissimilarity between found and and: 0.5113669633865356
# Cosine Similarity between found and happy: 0.45656535029411316
# Cosine Dissimilarity between found and happy: 0.5434346199035645
# Cosine Similarity between found and all: 0.44602787494659424
# Cosine Dissimilarity between found and all: 0.5539721250534058
# Cosine Similarity between found and everyday,: -0.17218098044395447
# Cosine Dissimilarity between found and everyday,: 1.1721810102462769
# Cosine Similarity between found and so: -0.3839891850948334
# Cosine Dissimilarity between found and so: 1.3839892148971558
# Cosine Similarity between found and light: -0.2639862298965454
# Cosine Dissimilarity between found and light: 1.2639862298965454
# Cosine Similarity between found and our: 0.0666605532169342
# Cosine Dissimilarity between found and our: 0.9333394765853882
# Cosine Similarity between found and my: -0.08896557986736298
# Cosine Dissimilarity between found and my: 1.0889655351638794
# Cosine Similarity between found and a: -0.04399849474430084
# Cosine Dissimilarity between found and a: 1.0439984798431396
# Cosine Similarity between found and are: 0.2806008458137512
# Cosine Dissimilarity between found and are: 0.7193991541862488
# Cosine Similarity between found and i've: 0.0010683045256882906
# Cosine Dissimilarity between found and i've: 0.9989317059516907
# Cosine Similarity between found and care: 0.45034295320510864
# Cosine Dissimilarity between found and care: 0.5496570467948914
# Cosine Similarity between found and i: 0.2406311184167862
# Cosine Dissimilarity between found and i: 0.759368896484375
# Cosine Similarity between found and friends: -0.24168723821640015
# Cosine Dissimilarity between found and friends: 1.241687297821045
# Cosine Similarity between found and today: 0.5166377425193787
# Cosine Dissimilarity between found and today: 0.48336225748062134
# Cosine Similarity between found and i'm: -0.14470672607421875
# Cosine Dissimilarity between found and i'm: 1.1447067260742188
# Cosine Similarity between found and scared: 0.01111385878175497
# Cosine Dissimilarity between found and scared: 0.9888861179351807
# Cosine Similarity between found and mirrors: -0.041387833654880524
# Cosine Dissimilarity between found and mirrors: 1.0413877964019775
# Cosine Similarity between found and for: 0.08555837720632553
# Cosine Dissimilarity between found and for: 0.9144416451454163
# Cosine Similarity between found and head: 0.03984156250953674
# Cosine Dissimilarity between found and head: 0.9601584672927856
# Cosine Similarity between found and daze: -0.018510019406676292
# Cosine Dissimilarity between found and daze: 1.0185099840164185
# Cosine Similarity between found and in: -0.18697072565555573
# Cosine Dissimilarity between found and in: 1.1869707107543945
# Cosine Similarity between found and morning: -0.2062900960445404
# Cosine Dissimilarity between found and morning: 1.2062901258468628
# Cosine Similarity between found and they're: 0.29630449414253235
# Cosine Dissimilarity between found and they're: 0.70369553565979
# Cosine Similarity between found and that's: 0.10611807554960251
# Cosine Dissimilarity between found and that's: 0.8938819169998169
# Cosine Similarity between is and okay,: -0.6610755920410156
# Cosine Dissimilarity between is and okay,: 1.6610755920410156
# Cosine Similarity between is and god: -0.5450412034988403
# Cosine Dissimilarity between is and god: 1.5450412034988403
# Cosine Similarity between is and candles: -0.22453923523426056
# Cosine Dissimilarity between is and candles: 1.2245392799377441
# Cosine Similarity between is and not: -0.20315492153167725
# Cosine Dissimilarity between is and not: 1.2031549215316772
# Cosine Similarity between is and you: 0.2334267795085907
# Cosine Dissimilarity between is and you: 0.7665731906890869
# Cosine Similarity between is and found: -0.1381683498620987
# Cosine Dissimilarity between is and found: 1.1381683349609375
# Cosine Similarity between is and is: 1.0000001192092896
# Cosine Dissimilarity between is and is: -1.1920928955078125e-07
# Cosine Similarity between is and 'cause: 0.0827224850654602
# Cosine Dissimilarity between is and 'cause: 0.9172775149345398
# Cosine Similarity between is and sunday: 0.3523026704788208
# Cosine Dissimilarity between is and sunday: 0.6476973295211792
# Cosine Similarity between is and broke: 0.09678728878498077
# Cosine Dissimilarity between is and broke: 0.9032127261161804
# Cosine Similarity between is and ugly,: -0.019764810800552368
# Cosine Dissimilarity between is and ugly,: 1.01976478099823
# Cosine Similarity between is and and: 0.04304414242506027
# Cosine Dissimilarity between is and and: 0.9569558501243591
# Cosine Similarity between is and happy: -0.26171258091926575
# Cosine Dissimilarity between is and happy: 1.2617125511169434
# Cosine Similarity between is and all: 0.5446611046791077
# Cosine Dissimilarity between is and all: 0.45533889532089233
# Cosine Similarity between is and everyday,: 0.2500547766685486
# Cosine Dissimilarity between is and everyday,: 0.7499452233314514
# Cosine Similarity between is and so: -0.0560755729675293
# Cosine Dissimilarity between is and so: 1.0560755729675293
# Cosine Similarity between is and light: -0.1057109460234642
# Cosine Dissimilarity between is and light: 1.1057109832763672
# Cosine Similarity between is and our: 0.050334006547927856
# Cosine Dissimilarity between is and our: 0.9496660232543945
# Cosine Similarity between is and my: -0.16095393896102905
# Cosine Dissimilarity between is and my: 1.1609539985656738
# Cosine Similarity between is and a: -0.6630870699882507
# Cosine Dissimilarity between is and a: 1.6630871295928955
# Cosine Similarity between is and are: -0.46995359659194946
# Cosine Dissimilarity between is and are: 1.4699535369873047
# Cosine Similarity between is and i've: -0.12160167843103409
# Cosine Dissimilarity between is and i've: 1.1216017007827759
# Cosine Similarity between is and care: 0.004340784624218941
# Cosine Dissimilarity between is and care: 0.9956592321395874
# Cosine Similarity between is and i: -0.2997520864009857
# Cosine Dissimilarity between is and i: 1.299752116203308
# Cosine Similarity between is and friends: -0.1573285162448883
# Cosine Dissimilarity between is and friends: 1.157328486442566
# Cosine Similarity between is and today: 0.34130892157554626
# Cosine Dissimilarity between is and today: 0.6586910486221313
# Cosine Similarity between is and i'm: 0.01167386770248413
# Cosine Dissimilarity between is and i'm: 0.9883261322975159
# Cosine Similarity between is and scared: -0.2907893657684326
# Cosine Dissimilarity between is and scared: 1.2907893657684326
# Cosine Similarity between is and mirrors: 0.4976221024990082
# Cosine Dissimilarity between is and mirrors: 0.5023778676986694
# Cosine Similarity between is and for: 0.11467169970273972
# Cosine Dissimilarity between is and for: 0.8853282928466797
# Cosine Similarity between is and head: -0.4532313048839569
# Cosine Dissimilarity between is and head: 1.4532313346862793
# Cosine Similarity between is and daze: -0.3253589868545532
# Cosine Dissimilarity between is and daze: 1.3253589868545532
# Cosine Similarity between is and in: 0.20580872893333435
# Cosine Dissimilarity between is and in: 0.7941912412643433
# Cosine Similarity between is and morning: 0.45060527324676514
# Cosine Dissimilarity between is and morning: 0.5493947267532349
# Cosine Similarity between is and they're: -0.39557966589927673
# Cosine Dissimilarity between is and they're: 1.3955796957015991
# Cosine Similarity between is and that's: -0.14509162306785583
# Cosine Dissimilarity between is and that's: 1.1450916528701782
# Cosine Similarity between 'cause and okay,: -0.22449742257595062
# Cosine Dissimilarity between 'cause and okay,: 1.2244974374771118
# Cosine Similarity between 'cause and god: 0.17769154906272888
# Cosine Dissimilarity between 'cause and god: 0.8223084211349487
# Cosine Similarity between 'cause and candles: 0.05234187841415405
# Cosine Dissimilarity between 'cause and candles: 0.947658121585846
# Cosine Similarity between 'cause and not: 0.37514618039131165
# Cosine Dissimilarity between 'cause and not: 0.6248538494110107
# Cosine Similarity between 'cause and you: 0.1346234530210495
# Cosine Dissimilarity between 'cause and you: 0.8653765320777893
# Cosine Similarity between 'cause and found: 0.24726872146129608
# Cosine Dissimilarity between 'cause and found: 0.7527312636375427
# Cosine Similarity between 'cause and is: 0.0827224850654602
# Cosine Dissimilarity between 'cause and is: 0.9172775149345398
# Cosine Similarity between 'cause and 'cause: 1.0
# Cosine Dissimilarity between 'cause and 'cause: 0.0
# Cosine Similarity between 'cause and sunday: -0.5582138895988464
# Cosine Dissimilarity between 'cause and sunday: 1.5582139492034912
# Cosine Similarity between 'cause and broke: -0.14682471752166748
# Cosine Dissimilarity between 'cause and broke: 1.1468247175216675
# Cosine Similarity between 'cause and ugly,: 0.5858697891235352
# Cosine Dissimilarity between 'cause and ugly,: 0.41413021087646484
# Cosine Similarity between 'cause and and: -0.027139782905578613
# Cosine Dissimilarity between 'cause and and: 1.0271397829055786
# Cosine Similarity between 'cause and happy: 0.1432633399963379
# Cosine Dissimilarity between 'cause and happy: 0.8567366600036621
# Cosine Similarity between 'cause and all: 0.13693280518054962
# Cosine Dissimilarity between 'cause and all: 0.8630672097206116
# Cosine Similarity between 'cause and everyday,: 0.09399542212486267
# Cosine Dissimilarity between 'cause and everyday,: 0.9060045480728149
# Cosine Similarity between 'cause and so: -0.16136273741722107
# Cosine Dissimilarity between 'cause and so: 1.1613627672195435
# Cosine Similarity between 'cause and light: 0.19115377962589264
# Cosine Dissimilarity between 'cause and light: 0.8088462352752686
# Cosine Similarity between 'cause and our: -0.43399694561958313
# Cosine Dissimilarity between 'cause and our: 1.4339969158172607
# Cosine Similarity between 'cause and my: -0.25721102952957153
# Cosine Dissimilarity between 'cause and my: 1.2572109699249268
# Cosine Similarity between 'cause and a: -0.029675811529159546
# Cosine Dissimilarity between 'cause and a: 1.029675841331482
# Cosine Similarity between 'cause and are: -0.06233277916908264
# Cosine Dissimilarity between 'cause and are: 1.0623327493667603
# Cosine Similarity between 'cause and i've: 0.04318365082144737
# Cosine Dissimilarity between 'cause and i've: 0.9568163752555847
# Cosine Similarity between 'cause and care: 0.11206606030464172
# Cosine Dissimilarity between 'cause and care: 0.8879339694976807
# Cosine Similarity between 'cause and i: -0.17244219779968262
# Cosine Dissimilarity between 'cause and i: 1.1724421977996826
# Cosine Similarity between 'cause and friends: -0.660542368888855
# Cosine Dissimilarity between 'cause and friends: 1.660542368888855
# Cosine Similarity between 'cause and today: -0.373322069644928
# Cosine Dissimilarity between 'cause and today: 1.3733220100402832
# Cosine Similarity between 'cause and i'm: 0.11913944780826569
# Cosine Dissimilarity between 'cause and i'm: 0.8808605670928955
# Cosine Similarity between 'cause and scared: 0.18679071962833405
# Cosine Dissimilarity between 'cause and scared: 0.8132092952728271
# Cosine Similarity between 'cause and mirrors: -0.42812296748161316
# Cosine Dissimilarity between 'cause and mirrors: 1.4281229972839355
# Cosine Similarity between 'cause and for: 0.11354333162307739
# Cosine Dissimilarity between 'cause and for: 0.8864566683769226
# Cosine Similarity between 'cause and head: 0.011344671249389648
# Cosine Dissimilarity between 'cause and head: 0.9886553287506104
# Cosine Similarity between 'cause and daze: -0.08950935304164886
# Cosine Dissimilarity between 'cause and daze: 1.08950936794281
# Cosine Similarity between 'cause and in: -0.22568191587924957
# Cosine Dissimilarity between 'cause and in: 1.2256819009780884
# Cosine Similarity between 'cause and morning: -0.3314376175403595
# Cosine Dissimilarity between 'cause and morning: 1.331437587738037
# Cosine Similarity between 'cause and they're: -0.2775784730911255
# Cosine Dissimilarity between 'cause and they're: 1.2775784730911255
# Cosine Similarity between 'cause and that's: 0.241099551320076
# Cosine Dissimilarity between 'cause and that's: 0.7589004635810852
# Cosine Similarity between sunday and okay,: -0.04638919234275818
# Cosine Dissimilarity between sunday and okay,: 1.0463892221450806
# Cosine Similarity between sunday and god: -0.7017813920974731
# Cosine Dissimilarity between sunday and god: 1.7017813920974731
# Cosine Similarity between sunday and candles: -0.005820423364639282
# Cosine Dissimilarity between sunday and candles: 1.005820393562317
# Cosine Similarity between sunday and not: -0.16504168510437012
# Cosine Dissimilarity between sunday and not: 1.1650416851043701
# Cosine Similarity between sunday and you: 0.14505669474601746
# Cosine Dissimilarity between sunday and you: 0.8549432754516602
# Cosine Similarity between sunday and found: -0.5406637787818909
# Cosine Dissimilarity between sunday and found: 1.540663719177246
# Cosine Similarity between sunday and is: 0.3523026704788208
# Cosine Dissimilarity between sunday and is: 0.6476973295211792
# Cosine Similarity between sunday and 'cause: -0.5582138895988464
# Cosine Dissimilarity between sunday and 'cause: 1.5582139492034912
# Cosine Similarity between sunday and sunday: 1.0000001192092896
# Cosine Dissimilarity between sunday and sunday: -1.1920928955078125e-07
# Cosine Similarity between sunday and broke: 0.2652689218521118
# Cosine Dissimilarity between sunday and broke: 0.7347310781478882
# Cosine Similarity between sunday and ugly,: -0.3026873767375946
# Cosine Dissimilarity between sunday and ugly,: 1.302687406539917
# Cosine Similarity between sunday and and: -0.35450348258018494
# Cosine Dissimilarity between sunday and and: 1.3545035123825073
# Cosine Similarity between sunday and happy: -0.21831052005290985
# Cosine Dissimilarity between sunday and happy: 1.2183104753494263
# Cosine Similarity between sunday and all: -0.1986120343208313
# Cosine Dissimilarity between sunday and all: 1.1986119747161865
# Cosine Similarity between sunday and everyday,: 0.5626065135002136
# Cosine Dissimilarity between sunday and everyday,: 0.4373934864997864
# Cosine Similarity between sunday and so: 0.04184415563941002
# Cosine Dissimilarity between sunday and so: 0.9581558704376221
# Cosine Similarity between sunday and light: 0.11736243963241577
# Cosine Dissimilarity between sunday and light: 0.8826375603675842
# Cosine Similarity between sunday and our: -0.07483020424842834
# Cosine Dissimilarity between sunday and our: 1.074830174446106
# Cosine Similarity between sunday and my: 0.2785260081291199
# Cosine Dissimilarity between sunday and my: 0.7214739918708801
# Cosine Similarity between sunday and a: 0.0038613975048065186
# Cosine Dissimilarity between sunday and a: 0.9961385726928711
# Cosine Similarity between sunday and are: -0.3212156891822815
# Cosine Dissimilarity between sunday and are: 1.3212156295776367
# Cosine Similarity between sunday and i've: 0.08334091305732727
# Cosine Dissimilarity between sunday and i've: 0.9166591167449951
# Cosine Similarity between sunday and care: -0.3138527274131775
# Cosine Dissimilarity between sunday and care: 1.3138527870178223
# Cosine Similarity between sunday and i: -0.2893928289413452
# Cosine Dissimilarity between sunday and i: 1.2893928289413452
# Cosine Similarity between sunday and friends: 0.5244592428207397
# Cosine Dissimilarity between sunday and friends: 0.47554075717926025
# Cosine Similarity between sunday and today: 0.14051848649978638
# Cosine Dissimilarity between sunday and today: 0.8594815135002136
# Cosine Similarity between sunday and i'm: -0.19532045722007751
# Cosine Dissimilarity between sunday and i'm: 1.1953204870224
# Cosine Similarity between sunday and scared: -0.16172626614570618
# Cosine Dissimilarity between sunday and scared: 1.1617262363433838
# Cosine Similarity between sunday and mirrors: 0.38909289240837097
# Cosine Dissimilarity between sunday and mirrors: 0.6109070777893066
# Cosine Similarity between sunday and for: 0.16497595608234406
# Cosine Dissimilarity between sunday and for: 0.8350240588188171
# Cosine Similarity between sunday and head: -0.22897204756736755
# Cosine Dissimilarity between sunday and head: 1.22897207736969
# Cosine Similarity between sunday and daze: -0.08679617941379547
# Cosine Dissimilarity between sunday and daze: 1.0867961645126343
# Cosine Similarity between sunday and in: 0.6164041757583618
# Cosine Dissimilarity between sunday and in: 0.3835958242416382
# Cosine Similarity between sunday and morning: 0.5550559759140015
# Cosine Dissimilarity between sunday and morning: 0.44494402408599854
# Cosine Similarity between sunday and they're: 0.0357515811920166
# Cosine Dissimilarity between sunday and they're: 0.9642484188079834
# Cosine Similarity between sunday and that's: -0.5005460977554321
# Cosine Dissimilarity between sunday and that's: 1.5005460977554321
# Cosine Similarity between broke and okay,: -0.058269597589969635
# Cosine Dissimilarity between broke and okay,: 1.0582696199417114
# Cosine Similarity between broke and god: -0.647267758846283
# Cosine Dissimilarity between broke and god: 1.6472678184509277
# Cosine Similarity between broke and candles: -0.5644981265068054
# Cosine Dissimilarity between broke and candles: 1.5644981861114502
# Cosine Similarity between broke and not: -0.14624515175819397
# Cosine Dissimilarity between broke and not: 1.1462451219558716
# Cosine Similarity between broke and you: 0.6483848094940186
# Cosine Dissimilarity between broke and you: 0.35161519050598145
# Cosine Similarity between broke and found: -0.6607285737991333
# Cosine Dissimilarity between broke and found: 1.6607285737991333
# Cosine Similarity between broke and is: 0.09678728878498077
# Cosine Dissimilarity between broke and is: 0.9032127261161804
# Cosine Similarity between broke and 'cause: -0.14682471752166748
# Cosine Dissimilarity between broke and 'cause: 1.1468247175216675
# Cosine Similarity between broke and sunday: 0.2652689218521118
# Cosine Dissimilarity between broke and sunday: 0.7347310781478882
# Cosine Similarity between broke and broke: 1.0000001192092896
# Cosine Dissimilarity between broke and broke: -1.1920928955078125e-07
# Cosine Similarity between broke and ugly,: 0.2388719767332077
# Cosine Dissimilarity between broke and ugly,: 0.7611280083656311
# Cosine Similarity between broke and and: 0.0687793418765068
# Cosine Dissimilarity between broke and and: 0.9312206506729126
# Cosine Similarity between broke and happy: 0.01968674175441265
# Cosine Dissimilarity between broke and happy: 0.980313241481781
# Cosine Similarity between broke and all: -0.3077360689640045
# Cosine Dissimilarity between broke and all: 1.3077360391616821
# Cosine Similarity between broke and everyday,: -0.12234321981668472
# Cosine Dissimilarity between broke and everyday,: 1.1223431825637817
# Cosine Similarity between broke and so: 0.2735375165939331
# Cosine Dissimilarity between broke and so: 0.7264624834060669
# Cosine Similarity between broke and light: 0.05922491103410721
# Cosine Dissimilarity between broke and light: 0.9407750964164734
# Cosine Similarity between broke and our: 0.29193443059921265
# Cosine Dissimilarity between broke and our: 0.7080655694007874
# Cosine Similarity between broke and my: -0.22386446595191956
# Cosine Dissimilarity between broke and my: 1.2238644361495972
# Cosine Similarity between broke and a: 0.1622551679611206
# Cosine Dissimilarity between broke and a: 0.8377448320388794
# Cosine Similarity between broke and are: 0.03158099576830864
# Cosine Dissimilarity between broke and are: 0.9684190154075623
# Cosine Similarity between broke and i've: 0.3636360466480255
# Cosine Dissimilarity between broke and i've: 0.6363639831542969
# Cosine Similarity between broke and care: -0.27790576219558716
# Cosine Dissimilarity between broke and care: 1.2779057025909424
# Cosine Similarity between broke and i: -0.25459733605384827
# Cosine Dissimilarity between broke and i: 1.2545973062515259
# Cosine Similarity between broke and friends: -0.12240494042634964
# Cosine Dissimilarity between broke and friends: 1.122404932975769
# Cosine Similarity between broke and today: -0.4378320574760437
# Cosine Dissimilarity between broke and today: 1.4378321170806885
# Cosine Similarity between broke and i'm: -0.05206596851348877
# Cosine Dissimilarity between broke and i'm: 1.0520659685134888
# Cosine Similarity between broke and scared: 0.23799985647201538
# Cosine Dissimilarity between broke and scared: 0.7620001435279846
# Cosine Similarity between broke and mirrors: -0.21543115377426147
# Cosine Dissimilarity between broke and mirrors: 1.2154312133789062
# Cosine Similarity between broke and for: -0.002786681056022644
# Cosine Dissimilarity between broke and for: 1.002786636352539
# Cosine Similarity between broke and head: 0.1919599175453186
# Cosine Dissimilarity between broke and head: 0.8080400824546814
# Cosine Similarity between broke and daze: -0.3835615813732147
# Cosine Dissimilarity between broke and daze: 1.383561611175537
# Cosine Similarity between broke and in: -0.0844784528017044
# Cosine Dissimilarity between broke and in: 1.084478497505188
# Cosine Similarity between broke and morning: 0.3472524881362915
# Cosine Dissimilarity between broke and morning: 0.6527475118637085
# Cosine Similarity between broke and they're: -0.3185836374759674
# Cosine Dissimilarity between broke and they're: 1.318583607673645
# Cosine Similarity between broke and that's: -0.05013396218419075
# Cosine Dissimilarity between broke and that's: 1.0501339435577393
# Cosine Similarity between ugly, and okay,: 0.08052393794059753
# Cosine Dissimilarity between ugly, and okay,: 0.9194760322570801
# Cosine Similarity between ugly, and god: 0.0032624751329421997
# Cosine Dissimilarity between ugly, and god: 0.996737539768219
# Cosine Similarity between ugly, and candles: -0.43664565682411194
# Cosine Dissimilarity between ugly, and candles: 1.4366456270217896
# Cosine Similarity between ugly, and not: 0.5545917749404907
# Cosine Dissimilarity between ugly, and not: 0.4454082250595093
# Cosine Similarity between ugly, and you: 0.33716633915901184
# Cosine Dissimilarity between ugly, and you: 0.6628336906433105
# Cosine Similarity between ugly, and found: -0.2761225998401642
# Cosine Dissimilarity between ugly, and found: 1.2761225700378418
# Cosine Similarity between ugly, and is: -0.019764810800552368
# Cosine Dissimilarity between ugly, and is: 1.01976478099823
# Cosine Similarity between ugly, and 'cause: 0.5858697891235352
# Cosine Dissimilarity between ugly, and 'cause: 0.41413021087646484
# Cosine Similarity between ugly, and sunday: -0.3026873767375946
# Cosine Dissimilarity between ugly, and sunday: 1.302687406539917
# Cosine Similarity between ugly, and broke: 0.2388719767332077
# Cosine Dissimilarity between ugly, and broke: 0.7611280083656311
# Cosine Similarity between ugly, and ugly,: 0.9999998807907104
# Cosine Dissimilarity between ugly, and ugly,: 1.1920928955078125e-07
# Cosine Similarity between ugly, and and: -0.1169479638338089
# Cosine Dissimilarity between ugly, and and: 1.1169480085372925
# Cosine Similarity between ugly, and happy: -0.006750438362360001
# Cosine Dissimilarity between ugly, and happy: 1.006750464439392
# Cosine Similarity between ugly, and all: -0.2615033984184265
# Cosine Dissimilarity between ugly, and all: 1.2615034580230713
# Cosine Similarity between ugly, and everyday,: 0.15589658915996552
# Cosine Dissimilarity between ugly, and everyday,: 0.8441033959388733
# Cosine Similarity between ugly, and so: 0.5537279844284058
# Cosine Dissimilarity between ugly, and so: 0.44627201557159424
# Cosine Similarity between ugly, and light: -0.28753331303596497
# Cosine Dissimilarity between ugly, and light: 1.2875332832336426
# Cosine Similarity between ugly, and our: -0.37194469571113586
# Cosine Dissimilarity between ugly, and our: 1.3719446659088135
# Cosine Similarity between ugly, and my: -0.11314298957586288
# Cosine Dissimilarity between ugly, and my: 1.113142967224121
# Cosine Similarity between ugly, and a: -0.12181273102760315
# Cosine Dissimilarity between ugly, and a: 1.1218127012252808
# Cosine Similarity between ugly, and are: -0.016025463119149208
# Cosine Dissimilarity between ugly, and are: 1.016025424003601
# Cosine Similarity between ugly, and i've: 0.24853166937828064
# Cosine Dissimilarity between ugly, and i've: 0.751468300819397
# Cosine Similarity between ugly, and care: 0.31983017921447754
# ...
# Cosine Dissimilarity between in and a: 0.6125658750534058
# Cosine Similarity between in and are: -0.35232362151145935
# Cosine Dissimilarity between in and are: 1.3523236513137817
# Cosine Similarity between in and i've: 0.335116982460022
# Cosine Dissimilarity between in and i've: 0.664883017539978
# Cosine Similarity between in and care: -0.6726564168930054
# Cosine Dissimilarity between in and care: 1.6726564168930054
# Cosine Similarity between in and i: -0.1368592381477356
# Cosine Dissimilarity between in and i: 1.1368591785430908
# Cosine Similarity between in and friends: 0.05617108941078186
# Cosine Dissimilarity between in and friends: 0.9438289403915405
# Cosine Similarity between in and today: 0.027853161096572876
# Cosine Dissimilarity between in and today: 0.9721468687057495
# Cosine Similarity between in and i'm: -0.08645819127559662
# Cosine Dissimilarity between in and i'm: 1.0864582061767578
# Cosine Similarity between in and scared: 0.06932464241981506
# Cosine Dissimilarity between in and scared: 0.9306753873825073
# Cosine Similarity between in and mirrors: 0.05581808090209961
# Cosine Dissimilarity between in and mirrors: 0.9441819190979004
# Cosine Similarity between in and for: 0.3048725128173828
# Cosine Dissimilarity between in and for: 0.6951274871826172
# Cosine Similarity between in and head: -0.59921795129776
# Cosine Dissimilarity between in and head: 1.5992178916931152
# Cosine Similarity between in and daze: 0.02207958698272705
# Cosine Dissimilarity between in and daze: 0.977920413017273
# Cosine Similarity between in and in: 1.0
# Cosine Dissimilarity between in and in: 0.0
# Cosine Similarity between in and morning: 0.4044228196144104
# Cosine Dissimilarity between in and morning: 0.5955771803855896
# Cosine Similarity between in and they're: 0.2567051649093628
# Cosine Dissimilarity between in and they're: 0.7432948350906372
# Cosine Similarity between in and that's: 0.04219552129507065
# Cosine Dissimilarity between in and that's: 0.9578045010566711
# Cosine Similarity between morning and okay,: -0.5358100533485413
# Cosine Dissimilarity between morning and okay,: 1.5358099937438965
# Cosine Similarity between morning and god: -0.4926530420780182
# Cosine Dissimilarity between morning and god: 1.4926530122756958
# Cosine Similarity between morning and candles: -0.2776449918746948
# Cosine Dissimilarity between morning and candles: 1.2776449918746948
# Cosine Similarity between morning and not: -0.6556693315505981
# Cosine Dissimilarity between morning and not: 1.6556693315505981
# Cosine Similarity between morning and you: 0.2508746087551117
# Cosine Dissimilarity between morning and you: 0.7491253614425659
# Cosine Similarity between morning and found: -0.2062900960445404
# Cosine Dissimilarity between morning and found: 1.2062901258468628
# Cosine Similarity between morning and is: 0.45060527324676514
# Cosine Dissimilarity between morning and is: 0.5493947267532349
# Cosine Similarity between morning and 'cause: -0.3314376175403595
# Cosine Dissimilarity between morning and 'cause: 1.331437587738037
# Cosine Similarity between morning and sunday: 0.5550559759140015
# Cosine Dissimilarity between morning and sunday: 0.44494402408599854
# Cosine Similarity between morning and broke: 0.3472524881362915
# Cosine Dissimilarity between morning and broke: 0.6527475118637085
# Cosine Similarity between morning and ugly,: -0.36641794443130493
# Cosine Dissimilarity between morning and ugly,: 1.3664178848266602
# Cosine Similarity between morning and and: 0.03457885980606079
# Cosine Dissimilarity between morning and and: 0.9654211401939392
# Cosine Similarity between morning and happy: 0.029492976143956184
# Cosine Dissimilarity between morning and happy: 0.970507025718689
# Cosine Similarity between morning and all: 0.11840780079364777
# Cosine Dissimilarity between morning and all: 0.8815922141075134
# Cosine Similarity between morning and everyday,: -0.061215780675411224
# Cosine Dissimilarity between morning and everyday,: 1.0612157583236694
# Cosine Similarity between morning and so: -0.026494193822145462
# Cosine Dissimilarity between morning and so: 1.0264941453933716
# Cosine Similarity between morning and light: -0.06434539705514908
# Cosine Dissimilarity between morning and light: 1.064345359802246
# Cosine Similarity between morning and our: 0.5194787979125977
# Cosine Dissimilarity between morning and our: 0.48052120208740234
# Cosine Similarity between morning and my: 0.1683400422334671
# Cosine Dissimilarity between morning and my: 0.8316599726676941
# Cosine Similarity between morning and a: 0.10245303809642792
# Cosine Dissimilarity between morning and a: 0.8975469470024109
# Cosine Similarity between morning and are: -0.043992429971694946
# Cosine Dissimilarity between morning and are: 1.0439924001693726
# Cosine Similarity between morning and i've: -0.0024954304099082947
# Cosine Dissimilarity between morning and i've: 1.0024954080581665
# Cosine Similarity between morning and care: -0.23209615051746368
# Cosine Dissimilarity between morning and care: 1.2320961952209473
# Cosine Similarity between morning and i: -0.6771395206451416
# Cosine Dissimilarity between morning and i: 1.6771395206451416
# Cosine Similarity between morning and friends: 0.01220393180847168
# Cosine Dissimilarity between morning and friends: 0.9877960681915283
# Cosine Similarity between morning and today: 0.2357361614704132
# Cosine Dissimilarity between morning and today: 0.7642638683319092
# Cosine Similarity between morning and i'm: -0.33007121086120605
# Cosine Dissimilarity between morning and i'm: 1.330071210861206
# Cosine Similarity between morning and scared: -0.5293356776237488
# Cosine Dissimilarity between morning and scared: 1.5293357372283936
# Cosine Similarity between morning and mirrors: 0.24818055331707
# Cosine Dissimilarity between morning and mirrors: 0.7518194317817688
# Cosine Similarity between morning and for: 0.4271507263183594
# Cosine Dissimilarity between morning and for: 0.5728492736816406
# Cosine Similarity between morning and head: -0.40512824058532715
# Cosine Dissimilarity between morning and head: 1.4051282405853271
# Cosine Similarity between morning and daze: 0.08410052955150604
# Cosine Dissimilarity between morning and daze: 0.9158994555473328
# Cosine Similarity between morning and in: 0.4044228196144104
# Cosine Dissimilarity between morning and in: 0.5955771803855896
# Cosine Similarity between morning and morning: 1.0000001192092896
# Cosine Dissimilarity between morning and morning: -1.1920928955078125e-07
# Cosine Similarity between morning and they're: -0.17640863358974457
# Cosine Dissimilarity between morning and they're: 1.1764086484909058
# Cosine Similarity between morning and that's: 0.017821751534938812
# Cosine Dissimilarity between morning and that's: 0.982178270816803
# Cosine Similarity between they're and okay,: 0.4292074143886566
# Cosine Dissimilarity between they're and okay,: 0.570792555809021
# Cosine Similarity between they're and god: 0.3157722055912018
# Cosine Dissimilarity between they're and god: 0.6842278242111206
# Cosine Similarity between they're and candles: 0.5385355949401855
# Cosine Dissimilarity between they're and candles: 0.46146440505981445
# Cosine Similarity between they're and not: -0.1880468726158142
# Cosine Dissimilarity between they're and not: 1.188046932220459
# Cosine Similarity between they're and you: -0.21310949325561523
# Cosine Dissimilarity between they're and you: 1.2131094932556152
# Cosine Similarity between they're and found: 0.29630449414253235
# Cosine Dissimilarity between they're and found: 0.70369553565979
# Cosine Similarity between they're and is: -0.39557966589927673
# Cosine Dissimilarity between they're and is: 1.3955796957015991
# Cosine Similarity between they're and 'cause: -0.2775784730911255
# Cosine Dissimilarity between they're and 'cause: 1.2775784730911255
# Cosine Similarity between they're and sunday: 0.0357515811920166
# Cosine Dissimilarity between they're and sunday: 0.9642484188079834
# Cosine Similarity between they're and broke: -0.3185836374759674
# Cosine Dissimilarity between they're and broke: 1.318583607673645
# Cosine Similarity between they're and ugly,: -0.6913114786148071
# Cosine Dissimilarity between they're and ugly,: 1.6913114786148071
# Cosine Similarity between they're and and: -0.1396084427833557
# Cosine Dissimilarity between they're and and: 1.139608383178711
# Cosine Similarity between they're and happy: 0.3053458631038666
# Cosine Dissimilarity between they're and happy: 0.694654107093811
# Cosine Similarity between they're and all: -0.24482569098472595
# Cosine Dissimilarity between they're and all: 1.2448257207870483
# Cosine Similarity between they're and everyday,: -0.14201658964157104
# Cosine Dissimilarity between they're and everyday,: 1.1420166492462158
# Cosine Similarity between they're and so: -0.4538843631744385
# Cosine Dissimilarity between they're and so: 1.4538843631744385
# Cosine Similarity between they're and light: 0.4849168360233307
# Cosine Dissimilarity between they're and light: 0.5150831937789917
# Cosine Similarity between they're and our: 0.08280695974826813
# Cosine Dissimilarity between they're and our: 0.9171930551528931
# Cosine Similarity between they're and my: -0.15193800628185272
# Cosine Dissimilarity between they're and my: 1.1519379615783691
# Cosine Similarity between they're and a: 0.2677651047706604
# Cosine Dissimilarity between they're and a: 0.7322348952293396
# Cosine Similarity between they're and are: 0.32416510581970215
# Cosine Dissimilarity between they're and are: 0.6758348941802979
# Cosine Similarity between they're and i've: -0.15237338840961456
# Cosine Dissimilarity between they're and i've: 1.1523734331130981
# Cosine Similarity between they're and care: -0.4095420837402344
# Cosine Dissimilarity between they're and care: 1.4095420837402344
# Cosine Similarity between they're and i: 0.25442975759506226
# Cosine Dissimilarity between they're and i: 0.7455702424049377
# Cosine Similarity between they're and friends: 0.07706720381975174
# Cosine Dissimilarity between they're and friends: 0.9229328036308289
# Cosine Similarity between they're and today: 0.0985724925994873
# Cosine Dissimilarity between they're and today: 0.9014275074005127
# Cosine Similarity between they're and i'm: 0.49333861470222473
# Cosine Dissimilarity between they're and i'm: 0.5066614151000977
# Cosine Similarity between they're and scared: 0.08532875776290894
# Cosine Dissimilarity between they're and scared: 0.9146712422370911
# Cosine Similarity between they're and mirrors: 0.25396907329559326
# Cosine Dissimilarity between they're and mirrors: 0.7460309267044067
# Cosine Similarity between they're and for: -0.3714814782142639
# Cosine Dissimilarity between they're and for: 1.3714814186096191
# Cosine Similarity between they're and head: 0.19883927702903748
# Cosine Dissimilarity between they're and head: 0.8011606931686401
# Cosine Similarity between they're and daze: 0.1706511378288269
# Cosine Dissimilarity between they're and daze: 0.8293488621711731
# Cosine Similarity between they're and in: 0.2567051649093628
# Cosine Dissimilarity between they're and in: 0.7432948350906372
# Cosine Similarity between they're and morning: -0.17640863358974457
# Cosine Dissimilarity between they're and morning: 1.1764086484909058
# Cosine Similarity between they're and they're: 1.0000001192092896
# Cosine Dissimilarity between they're and they're: -1.1920928955078125e-07
# Cosine Similarity between they're and that's: 0.11511512845754623
# Cosine Dissimilarity between they're and that's: 0.8848848938941956
# Cosine Similarity between that's and okay,: -0.10822876542806625
# Cosine Dissimilarity between that's and okay,: 1.1082288026809692
# Cosine Similarity between that's and god: 0.34517809748649597
# Cosine Dissimilarity between that's and god: 0.6548218727111816
# Cosine Similarity between that's and candles: 0.3170907497406006
# Cosine Dissimilarity between that's and candles: 0.6829092502593994
# Cosine Similarity between that's and not: -0.4321781396865845
# Cosine Dissimilarity between that's and not: 1.4321781396865845
# Cosine Similarity between that's and you: 0.21618619561195374
# Cosine Dissimilarity between that's and you: 0.7838138341903687
# Cosine Similarity between that's and found: 0.10611807554960251
# Cosine Dissimilarity between that's and found: 0.8938819169998169
# Cosine Similarity between that's and is: -0.14509162306785583
# Cosine Dissimilarity between that's and is: 1.1450916528701782
# Cosine Similarity between that's and 'cause: 0.241099551320076
# Cosine Dissimilarity between that's and 'cause: 0.7589004635810852
# Cosine Similarity between that's and sunday: -0.5005460977554321
# Cosine Dissimilarity between that's and sunday: 1.5005460977554321
# Cosine Similarity between that's and broke: -0.05013396218419075
# Cosine Dissimilarity between that's and broke: 1.0501339435577393
# Cosine Similarity between that's and ugly,: -0.14642947912216187
# Cosine Dissimilarity between that's and ugly,: 1.1464295387268066
# Cosine Similarity between that's and and: -0.1983441412448883
# Cosine Dissimilarity between that's and and: 1.198344111442566
# Cosine Similarity between that's and happy: 0.06744103133678436
# Cosine Dissimilarity between that's and happy: 0.9325589537620544
# Cosine Similarity between that's and all: 0.28696295619010925
# Cosine Dissimilarity between that's and all: 0.7130370140075684
# Cosine Similarity between that's and everyday,: -0.5813132524490356
# Cosine Dissimilarity between that's and everyday,: 1.5813132524490356
# Cosine Similarity between that's and so: -0.2551110088825226
# Cosine Dissimilarity between that's and so: 1.2551109790802002
# Cosine Similarity between that's and light: 0.43507659435272217
# Cosine Dissimilarity between that's and light: 0.5649234056472778
# Cosine Similarity between that's and our: 0.09797851741313934
# Cosine Dissimilarity between that's and our: 0.9020214676856995
# Cosine Similarity between that's and my: -0.41528064012527466
# Cosine Dissimilarity between that's and my: 1.4152805805206299
# Cosine Similarity between that's and a: 0.39507701992988586
# Cosine Dissimilarity between that's and a: 0.6049230098724365
# Cosine Similarity between that's and are: 0.28102922439575195
# Cosine Dissimilarity between that's and are: 0.718970775604248
# Cosine Similarity between that's and i've: -0.13708150386810303
# Cosine Dissimilarity between that's and i've: 1.137081503868103
# Cosine Similarity between that's and care: -0.2930206060409546
# Cosine Dissimilarity between that's and care: 1.2930206060409546
# Cosine Similarity between that's and i: 0.16547591984272003
# Cosine Dissimilarity between that's and i: 0.8345240950584412
# Cosine Similarity between that's and friends: -0.34245970845222473
# Cosine Dissimilarity between that's and friends: 1.3424596786499023
# Cosine Similarity between that's and today: -0.3617152273654938
# Cosine Dissimilarity between that's and today: 1.3617151975631714
# Cosine Similarity between that's and i'm: 0.12959028780460358
# Cosine Dissimilarity between that's and i'm: 0.8704097270965576
# Cosine Similarity between that's and scared: -0.12760184705257416
# Cosine Dissimilarity between that's and scared: 1.1276018619537354
# Cosine Similarity between that's and mirrors: -0.190805584192276
# Cosine Dissimilarity between that's and mirrors: 1.1908055543899536
# Cosine Similarity between that's and for: 0.2393421232700348
# Cosine Dissimilarity between that's and for: 0.7606579065322876
# Cosine Similarity between that's and head: 0.04244157671928406
# Cosine Dissimilarity between that's and head: 0.9575583934783936
# Cosine Similarity between that's and daze: 0.5070499181747437
# Cosine Dissimilarity between that's and daze: 0.49295008182525635
# Cosine Similarity between that's and in: 0.04219552129507065
# Cosine Dissimilarity between that's and in: 0.9578045010566711
# Cosine Similarity between that's and morning: 0.017821751534938812
# Cosine Dissimilarity between that's and morning: 0.982178270816803
# Cosine Similarity between that's and they're: 0.11511512845754623
# Cosine Dissimilarity between that's and they're: 0.8848848938941956
# Cosine Similarity between that's and that's: 1.0
# Cosine Dissimilarity between that's and that's: 0.0
